# %%
import os, cv2, torch, timm, warnings, librosa, torchaudio, math, re, csv, json
import numpy as np
import torch.nn.functional as F
from torchsummary import summary

from timm.models.layers import trunc_normal_
from timm.models.vision_transformer import Block, PatchEmbed

from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms as T
from scipy.io.wavfile import read
from scipy.io import wavfile
from scipy.signal import spectrogram

# %%
pattern = re.compile('(\s*)playing(\s*)') # this is for removing word playing from vggsound classes
path='/home/vin/Documents/ITU/thesis/data'
vgg_csv_path=path+'/vgg/raw/filtered_vggsound.csv'

dataset=list()
with open(vgg_csv_path, 'r', newline='') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    for id_,val,label,_ in csv_reader:
        l = pattern.sub('',label)
        l = l.replace(',','_')
        l = l.replace(' ','_')
        vid_id = id_+'_'+ "%06d" % (int(val))
        final_dest = path+'/'+'vgg/preprocessed/'+l+'/video/'+vid_id+'/'
        f = open(final_dest+vid_id+'.json',) 
        dataset.append(np.array(json.load(f)))
        print(final_dest)
# Out:
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/--G-wKyj6JQ_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bassoon/video/--I3Bjp_ptc_000254/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/piano/video/--IOqc-XgYo_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harp/video/--SQyOb8eS0_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_guitar/video/--gJvz9RrfA_000013/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/violin__fiddle/video/--iY3Bf4hDg_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bongo/video/--nzKFQ7Myg_000109/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/erhu/video/--q1RQWxQog_000093/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_guitar/video/--qXTWmzUKA_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electronic_organ/video/--rs27ZwZ9M_000022/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electronic_organ/video/--rs27ZwZ9M_000189/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/congas/video/--veKG73Di4_000039/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/congas/video/--veKG73Di4_000083/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/--yJcmmwiMc_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harmonica/video/-00nar1nEPc_000033/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/piano/video/-03Hd0MBgQY_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/steel_guitar__slide_guitar/video/-0HxntVOLW4_000508/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_drum/video/-0LtujdJBYA_000085/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/double_bass/video/-0UuUoXQUoI_000107/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cello/video/-0UyIRbzhlw_000026/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electric_guitar/video/-0WZoijgWto_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/didgeridoo/video/-0dzLw4NyrM_000596/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/glockenspiel/video/-0gYWIOfqdM_000046/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/oboe/video/-0iEMffOYwo_000005/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/-0jbsobEJg8_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/-0jbsobEJg8_000022/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_drum/video/-0legLrA6Ns_000051/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_drum/video/-0legLrA6Ns_000061/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cornet/video/-0mLdC1zRx8_000016/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tabla/video/-10VmSN3WzE_000159/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tabla/video/-10VmSN3WzE_000218/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-12PNUDVUjA_000029/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/washboard/video/-1C5GLtgcbY_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/washboard/video/-1C5GLtgcbY_000060/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bagpipes/video/-1KVzbdvkdg_000006/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bagpipes/video/-1KVzbdvkdg_000054/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trumpet/video/-1LGZONdjkY_000022/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trumpet/video/-1LGZONdjkY_000064/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/-1M0nMXxvHY_000043/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/banjo/video/-1P74acOb3c_000050/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-1XBP-nZ1bQ_000090/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/flute/video/-1gKqs5p3I8_000107/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/synthesizer/video/-1iK6drewCE_000184/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/synthesizer/video/-1iK6drewCE_000349/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/accordion/video/-1qyr-IzqKY_000060/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/drum_kit/video/-1ukRC9M6bc_000050/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trombone/video/-1vr3JMt_tc_000249/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/lacrosse/video/-2OrscQ9MKw_000185/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/timpani/video/-2PCw_b6c2k_000116/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-2TjevpJuAs_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/saxophone/video/-2Z9JGG0Dnw_000070/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bagpipes/video/-2bOwXoTATM_000373/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/french_horn/video/-2gf4GmIplE_000120/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bagpipes/video/

# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cornet/video/-BmsJloyzzQ_000111/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cornet/video/-BmsJloyzzQ_000125/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electric_guitar/video/-BnVmMjp0d4_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/violin__fiddle/video/-BpMHfa2Saw_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-BpgDEXKdx4_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/synthesizer/video/-By6I234TSs_000010/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/piano/video/-C66I4YOr4o_000270/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-C96gWRdNVM_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/snare_drum/video/-CI9mVOAK-k_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cornet/video/-CvYwNYacwE_000007/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/cornet/video/-CvYwNYacwE_000035/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trombone/video/-CxXxHczP_c_000010/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/hammond_organ/video/-Cyez43J6OQ_000171/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harmonica/video/-D0f4exnx9M_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harmonica/video/-D0f4exnx9M_000005/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electronic_organ/video/-D2SxTNIZic_000132/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bass_guitar/video/-D2vxENQgkY_000127/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/mandolin/video/-D4bZN69nd0_000356/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tabla/video/-D58XABgrM8_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tabla/video/-D58XABgrM8_000058/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/sitar/video/-D5NIadksMo_000038/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/sitar/video/-D5NIadksMo_000049/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/marimba__xylophone/video/-D7Od7iYq0A_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/-D9HD2eetiQ_000012/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harpsichord/video/-D9HD2eetiQ_000037/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/steel_guitar__slide_guitar/video/-DJBhehSljQ_000052/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/steel_guitar__slide_guitar/video/-DJBhehSljQ_000084/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/timpani/video/-DnZ_ZY3lgA_000160/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/accordion/video/-Dqi6nNtnWI_000060/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/double_bass/video/-DwwSHC2jLs_000102/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/electric_guitar/video/-E-5957s3RU_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/saxophone/video/-E1Iu6YRIkc_000000/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-E1zyCQE3es_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/snare_drum/video/-E5O64NnqeM_000009/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/banjo/video/-ECRgvDx4xc_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trumpet/video/-EOHzvnHYPE_000200/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/timbales/video/-EexFpwt15A_000018/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/timbales/video/-EexFpwt15A_000029/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/trombone/video/-EjUpvGSXcw_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/castanets/video/-Ezk-jIm6kM_000170/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/bagpipes/video/-F6whO1LVKc_000210/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-FIGpCo9VoM_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-FLztWOwCRI_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/drum_kit/video/-FMH8bwF9iQ_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tambourine/video/-FPtSvIoxFY_000076/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/tambourine/video/-FPtSvIoxFY_000087/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/shofar/video/-FRfHI_8irw_000002/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/double_bass/video/-F_2cDPs7-4_000001/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/double_bass/video/-F_2cDPs7-4_000504/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-FcB1UrcL0E_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/steelpan/video/-FfFD4bbCEI_000002/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/steelpan/video/-FfFD4bbCEI_000018/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/piano/video/-FlSh-N35M0_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/harmonica/video/-G-o-Y4WuaU_000139/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/acoustic_guitar/video/-G08iN_t2QQ_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/violin__fiddle/video/-G1KPf8-9l0_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/flute/video/-G4PtM_9GWY_000030/
# /home/vin/Documents/ITU/thesis/data/vgg/preprocessed/accordion/video/-G5JuwEUxjM_000030/
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#      14 final_dest = path+'/'+'vgg/preprocessed/'+l+'/video/'+vid_id+'/'
#      15 f = open(final_dest+vid_id+'.json',)
# ---> 16 dataset.append(np.array(json.load(f)))
#      17 print(final_dest)
#
# File /usr/lib/python3.8/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /usr/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File /usr/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.8/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 20574250 (char 20574249)

# %%
dataset = np.array(dataset)
batch=dataset.shape[0]
images=dataset.shape[1]

dataset = dataset.reshape(batch*images, 224, 224, 3)
print(dataset.shape)

eval_size = int(dataset.shape[0] * 0.9)

eval_ds = dataset[eval_size:]
train_ds = dataset[:eval_size]
# Out:
# (2680, 224, 224, 3)

# %%
class v_Encoder(torch.nn.Module):
    def __init__(self,
                 image_size=224,
                 patch_size=16,
                 emb_dim=1024, 
                 num_layer=12,
                 num_head=16,
                 mlp_ratio=4,
                 in_chans=3
                 ) -> None:
        super().__init__()
        self.patch_embed = PatchEmbed(image_size, patch_size, in_chans, emb_dim)
        num_patches = self.patch_embed.num_patches
        self.cls_token = torch.nn.Parameter(torch.zeros(1, 1, emb_dim))
        self.pos_embed = self.sincos_pos_embed()

        self.input = torch.nn.Conv2d(3, emb_dim, patch_size, patch_size)
        self.blocks = torch.nn.ModuleList([
            Block(emb_dim, num_head, mlp_ratio, qkv_bias=True, norm_layer=torch.nn.LayerNorm)
            for i in range(num_layer)])
        self.transformer = torch.nn.Sequential(*[Block(emb_dim, num_head) for _ in range(num_layer)])

        self.norm = torch.nn.LayerNorm(emb_dim)

        self.init_weight()

        
    def patchify(self,imgs):
        """
        imgs: (N, 3, H, W)
        x: (N, L, patch_size**2 *3) 
        N=number of images
        L=number of patches
        patch size=16
        """
        patch_embed = PatchEmbed(image_size, patch_size, in_chans, emb_dim)
        num_patches = patch_embed.num_patches
        p = patch_embed.patch_size[0] #
        assert imgs.shape[2] == imgs.shape[3] and imgs.shape[2] % p == 0

        h = w = imgs.shape[2] // p
        x = imgs.reshape(shape=(imgs.shape[0], 3, h, p, w, p))
        x = torch.einsum('nchpwq->nhwpqc', x)
        x = x.reshape(shape=(imgs.shape[0], h * w, p**2 * 3))
        return x

    def sincos_pos_embed(self,max_sequence_length = 197, embedding_dim=1024):

        position = torch.arange(0, max_sequence_length).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embedding_dim, 2) * -(math.log(10000.0) / embedding_dim))
        position_encoding = torch.zeros(1, max_sequence_length, embedding_dim)
        position_encoding[0, :, 0::2] = torch.sin(position * div_term)
        position_encoding[0, :, 1::2] = torch.cos(position * div_term)

        return position_encoding
    def random_masking(self,x, mask_ratio):

        N, L, D = x.shape  # batch, length, dim
        len_keep = int(L * (1 - mask_ratio))

        noise = torch.rand(N, L, device=x.device)  # noise in [0, 1]

        ids_shuffle = torch.argsort(noise, dim=1)  # ascend: small is keep, large is remove
        ids_restore = torch.argsort(ids_shuffle, dim=1)

        ids_keep = ids_shuffle[:, :len_keep]
        x_masked = torch.gather(x, dim=1, index=ids_keep.unsqueeze(-1).repeat(1, 1, D))

        mask = torch.ones([N, L], device=x.device)
        mask[:, :len_keep] = 0
        mask = torch.gather(mask, dim=1, index=ids_restore)

        return x_masked, mask, ids_restore

    def init_weight(self):
        trunc_normal_(self.cls_token, std=.02)
        trunc_normal_(self.pos_embed, std=.02)

    def forward(self, img):
        x = img.unsqueeze(0)
        x = torch.einsum('nhwc->nchw', x)
        x = self.patch_embed(x)
        x = x + self.pos_embed[:, 1:, :]
        x, mask, ids_restore = self.random_masking(x,0.75)
        cls_token = self.cls_token + self.pos_embed[:, :1, :]
        cls_tokens = cls_token.expand(x.shape[0], -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        for blk in self.blocks:
            x = blk(x)
        x = self.norm(x)
        
        return x, mask, ids_restore

class v_Decoder(torch.nn.Module):
    def __init__(self,
                 image_size=224,
                 patch_size=16,
                 emb_dim=1024,
                 dec_emb_dim=512, 
                 num_layer=8,
                 num_head=16,
                 in_chans=3,
                 mlp_ratio=4,
                 ) -> None:
        super().__init__()
        self.patch_embed = PatchEmbed(image_size, patch_size, in_chans, emb_dim)
        #num_patches = self.patch_embed.num_patches
        self.cls_token = torch.nn.Parameter(torch.zeros(1, 1, emb_dim))
        self.pos_embed = self.sincos_pos_embed()
        
        self.decoder_embed = torch.nn.Linear(emb_dim, dec_emb_dim, bias=True)    
        self.blocks = torch.nn.ModuleList([
            Block(dec_emb_dim, num_head, mlp_ratio, qkv_bias=True, norm_layer=torch.nn.LayerNorm)
            for i in range(num_layer)])
        self.transformer = torch.nn.Sequential(*[Block(emb_dim, num_head) for _ in range(num_layer)])
        self.mask_token = torch.nn.Parameter(torch.zeros(1, 1, dec_emb_dim))
        self.norm = torch.nn.LayerNorm(dec_emb_dim)
        self.decoder_pred = torch.nn.Linear(dec_emb_dim, patch_size**2 * in_chans, bias=True)
        self.init_weight()
        
    def unpatchify(self,x):
        patch_embed = self.patch_embed
        num_patches = patch_embed.num_patches
        p = patch_embed.patch_size[0]
        h = w = int(x.shape[1]**.5)
        assert h * w == x.shape[1]

        x = x.reshape(shape=(x.shape[0], h, w, p, p, 3))
        x = torch.einsum('nhwpqc->nchpwq', x)
        img = x.reshape(shape=(x.shape[0], 3, h * p, h * p))
        return img

    def sincos_pos_embed(self,max_sequence_length = 197, embedding_dim=512):

        position = torch.arange(0, max_sequence_length).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embedding_dim, 2) * -(math.log(10000.0) / embedding_dim))
        position_encoding = torch.zeros(1, max_sequence_length, embedding_dim)
        position_encoding[0, :, 0::2] = torch.sin(position * div_term)
        position_encoding[0, :, 1::2] = torch.cos(position * div_term)

        return position_encoding
    
    def init_weight(self):
        trunc_normal_(self.cls_token, std=.02)
        trunc_normal_(self.pos_embed, std=.02)

    def forward(self, x, ids_restore):
        
        x = self.decoder_embed(x)
        mask_tokens = self.mask_token.repeat(x.shape[0], ids_restore.shape[1] + 1 - x.shape[1], 1)
        x_ = torch.cat([x[:, 1:, :], mask_tokens], dim=1)  
        x_ = torch.gather(x_, dim=1, index=ids_restore.unsqueeze(-1).repeat(1, 1, x.shape[2]))  
        x = torch.cat([x[:, :1, :], x_], dim=1) 
        x = x + self.pos_embed
        for blk in self.blocks:
            x = blk(x)
        x = self.norm(x)
        x = self.decoder_pred(x)
        x = x[:, 1:, :]
        x = self.unpatchify(x).squeeze(0)
        x = torch.einsum('chw->hwc', x)
        
        return x.to(torch.float64)

# %%
encoder = v_Encoder()
decoder = v_Decoder()
img = torch.Tensor(train_ds[-1:].reshape(224,224,3))
x, _, ids_restore = encoder(img)
pred_img = decoder(x,ids_restore)
pred_img.shape
# Out:
# torch.Size([224, 224, 3])

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

data_loader = DataLoader(train_ds,batch_size=1,shuffle=False)

class V_MAE(torch.nn.Module):
    def __init__(self):
        super(V_MAE, self).__init__()

        self.encoder = v_Encoder()
        self.decoder = v_Decoder()
        
        
    def forward(self, x):
        x, mask, ids_restore = encoder(img)
        
        pred_img = decoder(x,ids_restore)
        
        return pred_img

model = V_MAE()
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = torch.nn.MSELoss()


epochs = 3
losses = []

for epoch in range(epochs):
    for d in data_loader:
        optimizer.zero_grad()
        pred_img = model(d.squeeze(0))
        loss = loss_function(pred_img, d.squeeze(0))
        loss.backward()
        optimizer.step()
        losses.append(loss)
        #print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')
#torch.save(autoencoder.state_dict(), 'autoencoder_model.pth')

# %%
plt.plot([values.data for values in losses])
plt.show()

# %%
plt.imshow(pred_img.data.to(torch.uint8))
plt.show()
